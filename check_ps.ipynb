# %%
from pixell import enmap, curvedsky
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
import importlib
import pandas as pd
import tools
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# /global/homes/h/hongbo/.conda/envs/myenv/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /global/homes/h/hongbo/.conda/envs/myenv/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /global/homes/h/hongbo/.conda/envs/myenv/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
repository_path = '/global/cscratch1/sd/hongbo/ksz_lens/'
data_path = '/global/cscratch1/sd/hongbo/ksz_lens/maps/cls'
smooth_ksz_lt_cls_file = '/global/cscratch1/sd/hongbo/ksz_lens/maps/websky/cls/\
smooth_ksz_lt_cls_7000.csv'
smooth_ksz_ri_cls_file = '/global/cscratch1/sd/hongbo/ksz_lens/maps/websky/cls/\
smooth_ksz_ri_cls_7000.csv'

# %%
smooth_ksz_lt_cls = pd.read_csv(smooth_ksz_lt_cls_file)
smooth_ksz_ri_cls = pd.read_csv(smooth_ksz_ri_cls_file)

# %%
plt.plot(smooth_ksz_lt_cls['ells'][30:], smooth_ksz_lt_cls['cls'][30:])
plt.plot(smooth_ksz_ri_cls['ells'][30:], smooth_ksz_ri_cls['cls'][30:])
plt.yscale('log')
plt.xscale('log')

# %%
realizations = 4
for r in range(realizations):
    ksz_g_alms = hp.synalm(smooth_ksz_lt_cls['cls'])
    ksz_g_cls = hp.alm2cl(ksz_g_alms)
    
    plt.plot(ksz_g_cls[30:], label='%s' %(r+1))

plt.legend()
plt.title('ksz realizations')
plt.yscale('log')
plt.xscale('log')
# Out:
# Text(0.5, 1.0, 'ksz realizations')
